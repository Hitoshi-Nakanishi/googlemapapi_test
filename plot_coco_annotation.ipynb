# %%
from IPython.display import Image
Image(filename='cvat/Screen Shot 2021-03-10 at 21.03.06.png')

# %%
Image(filename='cvat/Screen Shot 2021-03-10 at 21.03.19.png')

# %%
Image(filename='cvat/Screen Shot 2021-03-10 at 21.07.38.png')

# %%
import numpy as np
import io
import PIL.Image as Image
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
plt.rcParams['figure.figsize'] = (15.0, 15.0)

# %%
annfile = 'annotations/instances_default.json'
coco=COCO(annfile)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))
nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
# Out:
# COCO categories:
# parking
#
# COCO supercategories:

# %%
catIds = coco.getCatIds(catNms=['parking']);
imgIds = coco.getImgIds(catIds=catIds);
img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]
I = Image.open(img['file_name'])

annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds, iscrowd=None)
anns = coco.loadAnns(annIds)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(I)
ax.axis('off')
coco.showAnns(anns)
